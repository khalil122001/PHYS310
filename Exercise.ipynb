# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise 1
# a) Create a code that calculates A where A is defined as:
# $$A = \sum_1^n n $$

# %%
n = 20
A=np.sum(range(1,n+1))
print(A)
# Out:
# 210

# %% [markdown]
# b) Plot the value of A as n goes from 1 to 20

# %%
A_array=np.cumsum(range(0,n+1))
plt.plot(range(0,n+1),A_array)
plt.show()

# %% [markdown]
# c) Plot x and y with the following equations:
# $$
# \theta \in [0,2\pi] \\
# x = 16  \sin^3(\theta)\\
# y = 13  \cos(\theta) - 5 \cos(2\theta) - 2\cos(3\theta) - \cos(4\theta)
# $$

# %%
theta=np.arange(0,2*np.pi,0.1)
x=16*np.sin(theta)**3
y=13*np.cos(theta) - 5*np.cos(2*theta) - 2*np.cos(3*theta)  - np.cos(4*theta)
plt.plot(x,y,color='m')
plt.show()

# %% [markdown]
# # Exercise 2: The Collatz conjecture
#
# The Conjecture is the following :
# Given a number n $\in \mathbb{N}^+$ if it is even divide it by 2 and if it is odd multiply it by 3 and add 1.
# According to the conjecture this will always converge to 1.
#
# Write a code that calculates the steps of the Collatz Conjecture till it reches 1 and plot them.

# %%
# Fill in
Output=[]
n=200
while n!=1:
    if n%2 == 0:
       n=n/2
       Output.append(n)
    else:
        n=3*n+1
        Output.append(n)
plt.plot(Output)
plt.show()

# %% [markdown]
# # Exercise 3: Benford's Law.
#
# Benford’s law describes the relative frequency distribution for leading digits of numbers in datasets. Leading digits with smaller values occur more frequently than larger values. This law states that approximately 30% of numbers start with a 1 while less than 5% start with a 9. According to this law, leading 1s appear 6.5 times as often as leading 9s! Benford’s law is also known as the First Digit Law.
#
# We will be trying this using the world population for each contry in 'word_population.csv'.
# You have to load the data, only keep the first digit ( if the number is 1234 keep 1). Then histogram the values.

# %%
# Fill in
Data = np.loadtxt('world_population.csv',delimiter=',',usecols=(5),skiprows=1,dtype='str')
#print(Data)
#print(Data)
str_array=[x[0] for x in Data]
#print(str_array)
int_array=[]
for i in range(0,len(str_array)):
    j=int(str_array[i])
    int_array.append(j)
plt.hist(int_array)
plt.show()

# %% [markdown]
# # Linear Algebra

# %% [markdown]
# $$
# x + 5y + 5z = 18\\
# 8x + 14y -6z = 46\\
# 4x + 6y + 9z = 33\\
# $$
#
# Solve the system

# %%
A=[[1,5,5],[8,14,-6],[4,6,9]]
b=[18,46,33]
x=np.linalg.solve(A,b)
print(x)
# Out:
# [3. 2. 1.]

# %% [markdown]
# $$
# x + 2y = 4\\
# x + 2y = 5
# $$
# Solve the system with the best solution possible

# %%
A=[[1,2],[1,2]]
b=[4,5]
x=np.linalg.solve(A,b)
print(x)
#This obviously doens't work since there is no exact solution
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[47], line 3
#       1 A=[[1,2],[1,2]]
#       2 b=[4,5]
# ----> 3 x=np.linalg.solve(A,b)
#       4 print(x)
#
# File <__array_function__ internals>:5, in solve(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/linalg/linalg.py:393, in solve(a, b)
#     391 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     392 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 393 r = gufunc(a, b, signature=signature, extobj=extobj)
#     395 return wrap(r.astype(result_t, copy=False))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/linalg/linalg.py:88, in _raise_linalgerror_singular(err, flag)
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
